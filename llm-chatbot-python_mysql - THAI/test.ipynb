# %%
# Define inputs
inputs = [
    "ขอข้อมูล open ของหุ้น BBL วันที่ 2023-09-01",
]

# %%
# ตัวอย่างการทดสอบด้วย 100 คำถาม
questions_TH = [
    "บริษัท ADVANC มีสินทรัพย์รวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "บริษัท AOT มีหนี้สินรวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "กำไรสุทธิของบริษัท BBL ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "อัตราผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท BCP ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "สัดส่วนหนี้สินต่อทุน (D/E) ของบริษัท BDMS ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "รายได้รวมของบริษัท BEM ในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "กำไรสุทธิของบริษัท BGRIM ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "อัตรากำไรสุทธิ (Net Profit Margin) ของบริษัท BH ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "บริษัท BJC มีรายได้รวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "ค่าใช้จ่ายรวมของบริษัท BTS ในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "บริษัท CBG มีสินทรัพย์รวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "กำไรสุทธิของบริษัท CENTEL ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "อัตราผลตอบแทนต่อสินทรัพย์ (ROA) ของบริษัท CPALL ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "บริษัท CPF มีค่าใช้จ่ายรวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "บริษัท CPN มีอัตราส่วนหนี้สินต่อทุน (D/E) ในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "อัตราการหมุนเวียนสินทรัพย์ถาวร (Fixed Asset Turnover) ของบริษัท DELTA ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "บริษัท EA มีรายได้รวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "กำไรสุทธิของบริษัท EGCO ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "บริษัท GLOBAL มีรายได้รวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "บริษัท GPSC มีอัตราผลตอบแทนต่อผู้ถือหุ้น (ROE) ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "บริษัท GULF มีหนี้สินรวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "บริษัท HMPRO มีค่าใช้จ่ายรวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "บริษัท INTUCH มีอัตรากำไรสุทธิ (Net Profit Margin) ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "กำไรสุทธิของบริษัท IVL ในไตรมาสที่ 1 ปี 2019 คือเท่าไหร่",
    "บริษัท KBANK มีสินทรัพย์รวมในไตรมาสที่ 1 ปี 2019 เท่าไหร่",
    "ราคาปิดของหุ้น AWC ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "มูลค่าตลาด (Market Cap) ของหุ้น AOT ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราส่วนราคาต่อกำไร (P/E) ของหุ้น BDMS ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราการจ่ายเงินปันผล (Dividend Yield) ของหุ้น BBL ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ปริมาณการซื้อขายรวม (Total Volume) ของหุ้น BGRIM ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ราคาปิดของหุ้น BTS ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "มูลค่าตลาด (Market Cap) ของหุ้น CPALL ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราส่วนราคาต่อกำไร (P/E) ของหุ้น BEM ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ราคาต่ำสุด (Low) ของหุ้น DELTA ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราส่วนราคาต่อมูลค่าตามบัญชี (P/BV) ของหุ้น BCP ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "มูลค่าตลาด (Market Cap) ของหุ้น GPSC ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ราคาปิดของหุ้น TOP ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ปริมาณการซื้อขายรวม (Total Volume) ของหุ้น LH ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราส่วนราคาต่อมูลค่าตามบัญชี (P/BV) ของหุ้น KTC ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราส่วนราคาต่อกำไร (P/E) ของหุ้น PTTEP ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราการจ่ายเงินปันผล (Dividend Yield) ของหุ้น SCC ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "มูลค่าตลาด (Market Cap) ของหุ้น GULF ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ราคาปิดของหุ้น CENTEL ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ราคาสูงสุด (High) ของหุ้น IVL ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราส่วนราคาต่อมูลค่าตามบัญชี (P/BV) ของหุ้น TIDLOR ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "มูลค่าตลาด (Market Cap) ของหุ้น CBG ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ปริมาณการซื้อขายรวม (Total Volume) ของหุ้น AOT ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "อัตราส่วนราคาต่อกำไร (P/E) ของหุ้น CRC ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "ราคาปิดของหุ้น PTT ในวันที่ 1 กันยายน 2023 คือเท่าไหร่",
    "เปรียบเทียบสินทรัพย์รวมของบริษัท ADVANC กับบริษัท AOT ในปี 2019",
    "เปรียบเทียบหนี้สินรวมของบริษัท ADVANC กับบริษัท BBL ในปี 2019",
    "เปรียบเทียบรายได้รวมในไตรมาสของบริษัท ADVANC กับบริษัท CPALL ในไตรมาสที่ 3 ปี 2021",
    "เปรียบเทียบค่าใช้จ่ายรวมในไตรมาสของบริษัท ADVANC กับบริษัท AOT ในไตรมาสที่ 2 ปี 2020",
    "เปรียบเทียบกำไรสุทธิสะสมของบริษัท ADVANC ในปี 2020 กับปี 2021",
    "เปรียบเทียบกระแสเงินสดจากการดำเนินงานของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2021",
    "เปรียบเทียบผลตอบแทนต่อสินทรัพย์ (ROA) ของบริษัท ADVANC กับ AOT ในปี 2021",
    "เปรียบเทียบผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 กับปี 2022",
    "เปรียบเทียบราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 กับวันที่ 4 กันยายน 2023",
    "เปรียบเทียบอัตราส่วน PE ของหุ้น ADVANC กับหุ้น CPALL ในวันที่ 1 กันยายน 2023",
    "เปรียบเทียบมูลค่าตลาดของบริษัท ADVANC กับ AOT ในวันที่ 1 กันยายน 2023",
    "เปรียบเทียบสินทรัพย์รวมของบริษัท BBL กับบริษัท AOT ในปี 2020",
    "เปรียบเทียบกระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 กับไตรมาสที่ 4 ปี 2021",
    "เปรียบเทียบกำไรต่อหุ้น (EPS) ของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2020",
    "เปรียบเทียบอัตราหนี้สินต่อทุน (DE) ของบริษัท ADVANC กับ CPALL ในปี 2020",
    "เปรียบเทียบอัตราการหมุนเวียนสินทรัพย์รวมของบริษัท ADVANC ในปี 2021 กับปี 2022",
    "เปรียบเทียบอัตราการหมุนเวียนของสินทรัพย์ถาวรของบริษัท ADVANC กับ BBL ในปี 2020",
    "เปรียบเทียบกำไรสุทธิในไตรมาสของบริษัท ADVANC กับ AOT ในไตรมาสที่ 4 ปี 2021",
    "เปรียบเทียบปริมาณการซื้อขายของหุ้น ADVANC กับหุ้น BBL ในวันที่ 4 กันยายน 2023",
    "เปรียบเทียบราคาสูงสุดของหุ้น ADVANC กับหุ้น CPALL ในวันที่ 1 กันยายน 2023",
    "เปรียบเทียบการหมุนเวียนสินทรัพย์รวมของบริษัท ADVANC ในไตรมาสที่ 2 ปี 2021 กับไตรมาสที่ 4 ปี 2021",
    "เปรียบเทียบราคาต่ำสุดของหุ้น AOT กับหุ้น BBL ในวันที่ 1 กันยายน 2023",
    "เปรียบเทียบราคาปิดของหุ้น AOT กับหุ้น CPALL ในวันที่ 4 กันยายน 2023",
    "เปรียบเทียบมูลค่าตลาดของบริษัท CPALL กับ ADVANC ในวันที่ 4 กันยายน 2023",
    "เปรียบเทียบการหมุนเวียนของสินทรัพย์ถาวรของบริษัท CPALL กับ AOT ในปี 2021",
    "แนวโน้มของรายได้รวมของบริษัท ADVANC เปลี่ยนแปลงอย่างไรระหว่างปี 2019-2021",
    "สินทรัพย์รวมของ AOT มีการเปลี่ยนแปลงอย่างไรระหว่างปี 2019-2021",
    "การเปลี่ยนแปลงของกำไรสุทธิสะสมของบริษัท BBL ในช่วงปี 2019-2021 เป็นอย่างไร",
    "แนวโน้มของ EPS ของบริษัท BDMS เปลี่ยนแปลงไปอย่างไรในแต่ละไตรมาสของปี 2019",
    "แนวโน้มของกระแสเงินสดจากการดำเนินงานของ BGRIM ระหว่างปี 2019-2021 เป็นอย่างไร",
    "กำไรต่อหุ้น (EPS) ของบริษัท BH มีการเติบโตอย่างไรในปี 2019",
    "ค่าใช้จ่ายรวมของบริษัท BCP มีการเปลี่ยนแปลงอย่างไรในแต่ละไตรมาสของปี 2019",
    "แนวโน้มของการหมุนเวียนของสินทรัพย์รวมของบริษัท BTS ในแต่ละไตรมาสเป็นอย่างไร",
    "การเปลี่ยนแปลงของกำไรสุทธิสะสมของบริษัท CPN ระหว่างปี 2019-2021 เป็นอย่างไร",
    "แนวโน้มของรายได้รวมของบริษัท EA ในปี 2019-2021 เป็นอย่างไร",
    "อัตราส่วนหนี้สินต่อทุน (DE) ของ ADVANC มีการเปลี่ยนแปลงอย่างไรในแต่ละไตรมาสของปี 2019",
    "อัตราส่วน ROE ของบริษัท BDMS ส่งผลต่อความสามารถในการทำกำไรอย่างไร",
    "อัตราการหมุนเวียนของสินทรัพย์รวมของบริษัท BTS ส่งผลต่อการทำกำไรอย่างไรในปี 2019",
    "ผลตอบแทนต่อสินทรัพย์ (ROA) ของ BCP มีการเปลี่ยนแปลงอย่างไรในปี 2019",
    "การเปลี่ยนแปลงของอัตราส่วน PE ของ ADVANC ในปี 2019 ส่งผลต่อมูลค่าตลาดอย่างไร",
    "อัตราส่วน DE ของ AOT มีผลต่อความเสี่ยงทางการเงินอย่างไรในช่วงปี 2019-2021",
    "การเปลี่ยนแปลงของ ROA ของ BBL ในแต่ละไตรมาสของปี 2019 มีผลต่อประสิทธิภาพการใช้สินทรัพย์อย่างไร",
    "อัตราส่วนหนี้สินต่อทุน (DE) ของบริษัท CPF ส่งผลต่อความเสี่ยงทางการเงินอย่างไร",
    "อัตราผลตอบแทนผู้ถือหุ้น (ROE) ของ BDMS เปลี่ยนแปลงอย่างไรในปี 2019-2021",
    "อัตราส่วน ROE ของ BTS ส่งผลต่อการตัดสินใจของผู้ถือหุ้นอย่างไรในปี 2019",
    "อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ส่งผลต่อกำไรจากการดำเนินงานอย่างไร",
    "การเปลี่ยนแปลงของ P/E Ratio ของ BTS มีผลต่อการประเมินมูลค่าบริษัทอย่างไร",
    "การเติบโตของ ROE ของบริษัท AOT ส่งผลต่อการดึงดูดนักลงทุนอย่างไร",
    "การเพิ่มขึ้นของอัตราหนี้สินต่อทุน (DE) ของบริษัท BEM มีผลกระทบต่อความเสี่ยงทางการเงินอย่างไร",
    "ผลตอบแทนต่อสินทรัพย์ (ROA) ของ CPF ส่งผลต่อความสามารถในการใช้สินทรัพย์อย่างไรในปี 2019"
]

# Check the length of questions_TH to ensure it includes 100 questions
len(questions_TH)
# Out:
# 100

# %%
import pandas as pd
import streamlit as st
from bot import handle_submit  # Import the actual chatbot logic
# Out:
# 2025-04-05 15:37:17.750 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2025-04-05 15:37:18.118
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\china\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# ตัวอย่างการทดสอบด้วย 100 คำถาม
questions_TH2 = [

    "เปรียบเทียบค่าใช้จ่ายรวมในไตรมาสของบริษัท ADVANC กับบริษัท AOT ในไตรมาสที่ 2 ปี 2020",
    "เปรียบเทียบกำไรสุทธิสะสมของบริษัท ADVANC ในปี 2020 กับปี 2021",
    "เปรียบเทียบกระแสเงินสดจากการดำเนินงานของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2021",
    "เปรียบเทียบผลตอบแทนต่อสินทรัพย์ (ROA) ของบริษัท ADVANC กับ AOT ในปี 2021",
    "เปรียบเทียบผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 กับปี 2022",
    "เปรียบเทียบราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 กับวันที่ 4 กันยายน 2023",
    "เปรียบเทียบอัตราส่วน PE ของหุ้น ADVANC กับหุ้น CPALL ในวันที่ 1 กันยายน 2023",
    "เปรียบเทียบมูลค่าตลาดของบริษัท ADVANC กับ AOT ในวันที่ 1 กันยายน 2023",
    "เปรียบเทียบสินทรัพย์รวมของบริษัท BBL กับบริษัท AOT ในปี 2020",
    "เปรียบเทียบกระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 กับไตรมาสที่ 4 ปี 2021",
    "เปรียบเทียบกำไรต่อหุ้น (EPS) ของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2020",
    "เปรียบเทียบอัตราหนี้สินต่อทุน (DE) ของบริษัท ADVANC กับ CPALL ในปี 2020",
    "เปรียบเทียบอัตราการหมุนเวียนสินทรัพย์รวมของบริษัท ADVANC ในปี 2021 กับปี 2022",
    "เปรียบเทียบอัตราการหมุนเวียนของสินทรัพย์ถาวรของบริษัท ADVANC กับ BBL ในปี 2020",
    "เปรียบเทียบกำไรสุทธิในไตรมาสของบริษัท ADVANC กับ AOT ในไตรมาสที่ 4 ปี 2021",
    "เปรียบเทียบปริมาณการซื้อขายของหุ้น ADVANC กับหุ้น BBL ในวันที่ 4 กันยายน 2023",
    "เปรียบเทียบราคาสูงสุดของหุ้น ADVANC กับหุ้น CPALL ในวันที่ 1 กันยายน 2023",
    "เปรียบเทียบการหมุนเวียนสินทรัพย์รวมของบริษัท ADVANC ในไตรมาสที่ 2 ปี 2021 กับไตรมาสที่ 4 ปี 2021",
    "เปรียบเทียบราคาต่ำสุดของหุ้น AOT กับหุ้น BBL ในวันที่ 1 กันยายน 2023",
    "เปรียบเทียบราคาปิดของหุ้น AOT กับหุ้น CPALL ในวันที่ 4 กันยายน 2023",
    "เปรียบเทียบมูลค่าตลาดของบริษัท CPALL กับ ADVANC ในวันที่ 4 กันยายน 2023",
    "เปรียบเทียบการหมุนเวียนของสินทรัพย์ถาวรของบริษัท CPALL กับ AOT ในปี 2021",
    "แนวโน้มของรายได้รวมของบริษัท ADVANC เปลี่ยนแปลงอย่างไรระหว่างปี 2019-2021",
    "สินทรัพย์รวมของ AOT มีการเปลี่ยนแปลงอย่างไรระหว่างปี 2019-2021",
    "การเปลี่ยนแปลงของกำไรสุทธิสะสมของบริษัท BBL ในช่วงปี 2019-2021 เป็นอย่างไร",
    "แนวโน้มของ EPS ของบริษัท BDMS เปลี่ยนแปลงไปอย่างไรในแต่ละไตรมาสของปี 2019",
    "แนวโน้มของกระแสเงินสดจากการดำเนินงานของ BGRIM ระหว่างปี 2019-2021 เป็นอย่างไร",
    "กำไรต่อหุ้น (EPS) ของบริษัท BH มีการเติบโตอย่างไรในปี 2019",
    "ค่าใช้จ่ายรวมของบริษัท BCP มีการเปลี่ยนแปลงอย่างไรในแต่ละไตรมาสของปี 2019",
    "แนวโน้มของการหมุนเวียนของสินทรัพย์รวมของบริษัท BTS ในแต่ละไตรมาสเป็นอย่างไร",
    "การเปลี่ยนแปลงของกำไรสุทธิสะสมของบริษัท CPN ระหว่างปี 2019-2021 เป็นอย่างไร",
    "แนวโน้มของรายได้รวมของบริษัท EA ในปี 2019-2021 เป็นอย่างไร",
    "อัตราส่วนหนี้สินต่อทุน (DE) ของ ADVANC มีการเปลี่ยนแปลงอย่างไรในแต่ละไตรมาสของปี 2019",
    "อัตราส่วน ROE ของบริษัท BDMS ส่งผลต่อความสามารถในการทำกำไรอย่างไร",
    "อัตราการหมุนเวียนของสินทรัพย์รวมของบริษัท BTS ส่งผลต่อการทำกำไรอย่างไรในปี 2019",
    "ผลตอบแทนต่อสินทรัพย์ (ROA) ของ BCP มีการเปลี่ยนแปลงอย่างไรในปี 2019",
    "การเปลี่ยนแปลงของอัตราส่วน PE ของ ADVANC ในปี 2019 ส่งผลต่อมูลค่าตลาดอย่างไร",
    "อัตราส่วน DE ของ AOT มีผลต่อความเสี่ยงทางการเงินอย่างไรในช่วงปี 2019-2021",
    "การเปลี่ยนแปลงของ ROA ของ BBL ในแต่ละไตรมาสของปี 2019 มีผลต่อประสิทธิภาพการใช้สินทรัพย์อย่างไร",
    "อัตราส่วนหนี้สินต่อทุน (DE) ของบริษัท CPF ส่งผลต่อความเสี่ยงทางการเงินอย่างไร",
    "อัตราผลตอบแทนผู้ถือหุ้น (ROE) ของ BDMS เปลี่ยนแปลงอย่างไรในปี 2019-2021",
    "อัตราส่วน ROE ของ BTS ส่งผลต่อการตัดสินใจของผู้ถือหุ้นอย่างไรในปี 2019",
    "อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ส่งผลต่อกำไรจากการดำเนินงานอย่างไร",
    "การเปลี่ยนแปลงของ P/E Ratio ของ BTS มีผลต่อการประเมินมูลค่าบริษัทอย่างไร",
    "การเติบโตของ ROE ของบริษัท AOT ส่งผลต่อการดึงดูดนักลงทุนอย่างไร",
    "การเพิ่มขึ้นของอัตราหนี้สินต่อทุน (DE) ของบริษัท BEM มีผลกระทบต่อความเสี่ยงทางการเงินอย่างไร",
    "ผลตอบแทนต่อสินทรัพย์ (ROA) ของ CPF ส่งผลต่อความสามารถในการใช้สินทรัพย์อย่างไรในปี 2019"
]

# Check the length of questions_TH to ensure it includes 100 questions
len(questions_TH2)
# Out:
# 47

# %%
# Reset session state logs to ensure old data is not retained
st.session_state.query_logs = []

# Collect responses
for idx, user_input in enumerate(questions_TH2, start=1):
    print(f"Processing Input {idx}: {user_input}")
    try:
        # Call chatbot logic to get the response, metadata, and error
        response, metadata, error = handle_submit(user_input)
        print("**response",response)
        print("**metadata",metadata)
        # Log the response and metadata
        st.session_state.query_logs.append({
            "Sequence": idx,
            "Question": user_input,
            "Response": response if response else "Error occurred",
            "Query (SQL)": metadata.get("query", ""),
            "Query Generation Time (s)": round(metadata.get("query_generation_time", 0.0), 6),
            "Database Fetch Time (s)": round(metadata.get("database_fetch_time", 0.0), 8),
            "Response Generation Time (s)": round(metadata.get("response_generation_time", 0.0), 6),
            "Total Time (s)": round(
                metadata.get("query_generation_time", 0.0) +
                metadata.get("database_fetch_time", 0.0) +
                metadata.get("response_generation_time", 0.0),
                6
            ),
            "Error": error if error else "",
        })
    except Exception as e:
        print(f"Error processing input {idx}: {e}")
        # Log error if something goes wrong
        st.session_state.query_logs.append({
            "Sequence": idx,
            "Question": user_input,
            "Response": "Error occurred",
            "Query (SQL)": "",
            "Query Generation Time (s)": 0.0,
            "Database Fetch Time (s)": 0.0,
            "Response Generation Time (s)": 0.0,
            "Total Time (s)": 0.0,
            "Error": str(e),
        })

# Export logs to CSV file if there are any logs
if st.session_state.query_logs:
    logs_df = pd.DataFrame(st.session_state.query_logs)
    logs_df.to_csv("query_logs_th_2_53.csv", index=False, encoding="utf-8-sig")
    print("Logs exported to query_logs.csv")
else:
    print("No logs to export.")
# Out:
# Processing Input 1: เปรียบเทียบค่าใช้จ่ายรวมในไตรมาสของบริษัท ADVANC กับบริษัท AOT ในไตรมาสที่ 2 ปี 2020
# Raw user input: เปรียบเทียบค่าใช้จ่ายรวมในไตรมาสของบริษัท ADVANC กับบริษัท AOT ในไตรมาสที่ 2 ปี 2020
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: ADVANC, AOT, Q2 2020(    id  company_id  period_id  total_assets total_liabilities  \
# 0  209           1          6  368074033.00      296377565.00
# 1  210           2          6  178076696.56       30563944.58
#
#   paidup_share_capital shareholder_equity  total_equity total_revenue_quarter  \
# 0           2973554.00        71568629.00   71696468.00           42439919.00
# 1          14285700.00       146707907.21  147512751.99            1741404.42
#
#   total_revenue_accum  ... total_expenses_accum ebit_quarter   ebit_accum  \
# 0         85604183.00  ...          65902977.00   9957060.00  19613244.00
# 1         14006123.05  ...          12877785.51  -3567761.94   1180210.69
#
#   net_profit_quarter net_profit_accum eps_quarter eps_accum  \
# 0         7001114.00      13757308.00        2.35      4.63
# 1        -2933904.67        713740.49       -0.21      0.05
#
#   operating_cash_flow investing_cash_flow financing_cash_flow
# 0         42325235.99        -14632011.00        -21501162.00
# 1         -1149097.41         23066151.43        -17166231.99
#
# [2 rows x 21 columns], "SELECT * FROM financialmetrics WHERE company_id IN ((SELECT id FROM company WHERE symbol IN ('ADVANC', 'AOT'))) AND period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 2);", 20.8613543510437, 0.008132696151733398, None)Thought: Is it necessary to use a tool? No
# Final Answer: ค่าใช้จ่ายรวมในไตรมาสที่ 2 ปี 2020 ของบริษัท ADVANC คือ 65902977.00 บาท ส่วนบริษัท AOT คือ 12877785.51 บาท
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบค่าใช้จ่ายรวมในไตรมาสของบริษัท ADVANC กับบริษัท AOT ในไตรมาสที่ 2 ปี 2020', 'chat_history': [], 'query': "SELECT 'ADVANC' as company, fm1.total_expenses_quarter as total_expenses_quarter FROM financialmetrics fm1 WHERE fm1.company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND fm1.period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 2) UNION SELECT 'AOT', fm2.total_expenses_quarter FROM financialmetrics fm2 WHERE fm2.company_id = (SELECT id FROM company WHERE symbol = 'AOT') AND fm2.period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 2);", 'query_generation_time': 2.9431965351104736, 'database_fetch_time': 0.0054357051849365234, 'sql_error': None, 'output': 'ค่าใช้จ่ายรวมในไตรมาสที่ 2 ปี 2020 ของบริษัท ADVANC คือ 65902977.00 บาท ส่วนบริษัท AOT คือ 12877785.51 บาท'}
# Response generation time: 33.86339 seconds
# **response ค่าใช้จ่ายรวมในไตรมาสที่ 2 ปี 2020 ของบริษัท ADVANC คือ 65902977.00 บาท ส่วนบริษัท AOT คือ 12877785.51 บาท
# **metadata {'query': "SELECT 'ADVANC' as company, fm1.total_expenses_quarter as total_expenses_quarter FROM financialmetrics fm1 WHERE fm1.company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND fm1.period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 2) UNION SELECT 'AOT', fm2.total_expenses_quarter FROM financialmetrics fm2 WHERE fm2.company_id = (SELECT id FROM company WHERE symbol = 'AOT') AND fm2.period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 2);", 'response': 'ค่าใช้จ่ายรวมในไตรมาสที่ 2 ปี 2020 ของบริษัท ADVANC คือ 65902977.00 บาท ส่วนบริษัท AOT คือ 12877785.51 บาท', 'query_generation_time': 2.9431965351104736, 'database_fetch_time': 0.0054357051849365234, 'response_generation_time': 33.863391160964966, 'error': None}
# Processing Input 2: เปรียบเทียบกำไรสุทธิสะสมของบริษัท ADVANC ในปี 2020 กับปี 2021
# Raw user input: เปรียบเทียบกำไรสุทธิสะสมของบริษัท ADVANC ในปี 2020 กับปี 2021
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: ADVANC, 2020, 2021Error executing query: (mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row
# [SQL: SELECT * FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2020), (SELECT id FROM period WHERE year = 2021));]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# (Empty DataFrame
# Columns: []
# Index: [], "SELECT * FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2020), (SELECT id FROM period WHERE year = 2021));", 36.264227628707886, 0.0, "(mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row\n[SQL: SELECT * FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2020), (SELECT id FROM period WHERE year = 2021));]\n(Background on this error at: https://sqlalche.me/e/20/9h9h)")Thought: It seems like there's an issue with the database query. Let me try again with a different approach.
#
# Action: Financial Statements
# Action Input: ADVANC, 2020 Q4, 2021 Q4(  total_revenue_quarter
# 0           45863526.05
# 1           50585431.36, "SELECT total_revenue_quarter FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2020 AND quarter = 4), (SELECT id FROM period WHERE year = 2021 AND quarter = 4));", 35.89681816101074, 0.0, None)Thought: Is it necessary to use a tool? No
# Final Answer: จากผลที่ได้จาก_tool_ Financial Statements เราสามารถเห็นได้ว่าบริษัท ADVANC มีกำไรสุทธิสะสมในปี 2020 เท่ากับ 45,863,526.05 บาท และในปี 2021 เท่ากับ 50,585,431.36 บาท ดังนั้น กำไรสุทธิสะสมในปี 2021 สูงกว่าในปี 2020 ประมาณ 4,721,905.31 บาท หรือคิดเป็นร้อยละ 10.31 %.
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบกำไรสุทธิสะสมของบริษัท ADVANC ในปี 2020 กับปี 2021', 'chat_history': [], 'query': 'SELECT (SELECT net_profit_accum FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = \'ADVANC\') AND period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 4)) AS "2020", (SELECT net_profit_accum FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = \'ADVANC\') AND period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 4)) AS "2021";', 'query_generation_time': 36.012794971466064, 'database_fetch_time': 0.015018939971923828, 'sql_error': None, 'output': 'จากผลที่ได้จาก_tool_ Financial Statements เราสามารถเห็นได้ว่าบริษัท ADVANC มีกำไรสุทธิสะสมในปี 2020 เท่ากับ 45,863,526.05 บาท และในปี 2021 เท่ากับ 50,585,431.36 บาท ดังนั้น กำไรสุทธิสะสมในปี 2021 สูงกว่าในปี 2020 ประมาณ 4,721,905.31 บาท หรือคิดเป็นร้อยละ 10.31 %.'}
# Response generation time: 103.54726 seconds
# **response จากผลที่ได้จาก_tool_ Financial Statements เราสามารถเห็นได้ว่าบริษัท ADVANC มีกำไรสุทธิสะสมในปี 2020 เท่ากับ 45,863,526.05 บาท และในปี 2021 เท่ากับ 50,585,431.36 บาท ดังนั้น กำไรสุทธิสะสมในปี 2021 สูงกว่าในปี 2020 ประมาณ 4,721,905.31 บาท หรือคิดเป็นร้อยละ 10.31 %.
# **metadata {'query': 'SELECT (SELECT net_profit_accum FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = \'ADVANC\') AND period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 4)) AS "2020", (SELECT net_profit_accum FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = \'ADVANC\') AND period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 4)) AS "2021";', 'response': 'จากผลที่ได้จาก_tool_ Financial Statements เราสามารถเห็นได้ว่าบริษัท ADVANC มีกำไรสุทธิสะสมในปี 2020 เท่ากับ 45,863,526.05 บาท และในปี 2021 เท่ากับ 50,585,431.36 บาท ดังนั้น กำไรสุทธิสะสมในปี 2021 สูงกว่าในปี 2020 ประมาณ 4,721,905.31 บาท หรือคิดเป็นร้อยละ 10.31 %.', 'query_generation_time': 36.012794971466064, 'database_fetch_time': 0.015018939971923828, 'response_generation_time': 103.54725766181946, 'error': None}
# Processing Input 3: เปรียบเทียบกระแสเงินสดจากการดำเนินงานของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2021
# Raw user input: เปรียบเทียบกระแสเงินสดจากการดำเนินงานของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2021
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: ADVANC and BBL, Q1 2021(    id  company_id  period_id   total_assets total_liabilities  \
# 0  339           1          9   363733310.00      292075989.00
# 1  342           3          9  3952808572.00     3491106218.00
#
#   paidup_share_capital shareholder_equity  total_equity total_revenue_quarter  \
# 0           2973554.00        71531842.00   71657321.00           46083672.00
# 1          19088429.00       460208915.00  461702354.00           38019746.00
#
#   total_revenue_accum  ... total_expenses_accum ebit_quarter   ebit_accum  \
# 0         46083672.00  ...          36293096.00   9506866.00   9506866.00
# 1         38019746.00  ...          32195369.00  16590249.00  16590249.00
#
#   net_profit_quarter net_profit_accum eps_quarter eps_accum  \
# 0         6643889.00       6643889.00        2.23      2.23
# 1         6923096.00       6923096.00        3.63      3.63
#
#   operating_cash_flow investing_cash_flow financing_cash_flow
# 0         20764808.00        -14110393.00         -7301897.00
# 1        -89356740.00         76568343.00          2621006.00
#
# [2 rows x 21 columns], "SELECT * FROM financialmetrics WHERE company_id IN ((SELECT id FROM company WHERE symbol IN ('ADVANC', 'BBL'))) AND period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 1);", 34.87289786338806, 0.0, None)Thought: Is it necessary to use a tool? No
# Final Answer: จากข้อมูลด้านบน พบว่ากระแสเงินสดจากการดำเนินงานของ ADVANC ในไตรมาสที่ 1 ปี 2021 เท่ากับ 20,764,808 บาท ส่วน BBL เท่ากับ -89,356,740 บาท แสดงว่า ADVANC มีกระแสเงินสดจากการดำเนินงานสูงกว่า BBL ในไตรมาสที่ 1 ปี 2021
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบกระแสเงินสดจากการดำเนินงานของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2021', 'chat_history': [], 'query': "SELECT 'ADVANC' AS company, fm1.operating_cash_flow AS cash_flow FROM financialmetrics fm1 WHERE fm1.company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND fm1.period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 1) UNION SELECT 'BBL' AS company, fm2.operating_cash_flow AS cash_flow FROM financialmetrics fm2 WHERE fm2.company_id = (SELECT id FROM company WHERE symbol = 'BBL') AND fm2.period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 1);", 'query_generation_time': 36.09971332550049, 'database_fetch_time': 0.0020041465759277344, 'sql_error': None, 'output': 'จากข้อมูลด้านบน พบว่ากระแสเงินสดจากการดำเนินงานของ ADVANC ในไตรมาสที่ 1 ปี 2021 เท่ากับ 20,764,808 บาท ส่วน BBL เท่ากับ -89,356,740 บาท แสดงว่า ADVANC มีกระแสเงินสดจากการดำเนินงานสูงกว่า BBL ในไตรมาสที่ 1 ปี 2021'}
# Response generation time: 56.72565 seconds
# **response จากข้อมูลด้านบน พบว่ากระแสเงินสดจากการดำเนินงานของ ADVANC ในไตรมาสที่ 1 ปี 2021 เท่ากับ 20,764,808 บาท ส่วน BBL เท่ากับ -89,356,740 บาท แสดงว่า ADVANC มีกระแสเงินสดจากการดำเนินงานสูงกว่า BBL ในไตรมาสที่ 1 ปี 2021
# **metadata {'query': "SELECT 'ADVANC' AS company, fm1.operating_cash_flow AS cash_flow FROM financialmetrics fm1 WHERE fm1.company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND fm1.period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 1) UNION SELECT 'BBL' AS company, fm2.operating_cash_flow AS cash_flow FROM financialmetrics fm2 WHERE fm2.company_id = (SELECT id FROM company WHERE symbol = 'BBL') AND fm2.period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 1);", 'response': 'จากข้อมูลด้านบน พบว่ากระแสเงินสดจากการดำเนินงานของ ADVANC ในไตรมาสที่ 1 ปี 2021 เท่ากับ 20,764,808 บาท ส่วน BBL เท่ากับ -89,356,740 บาท แสดงว่า ADVANC มีกระแสเงินสดจากการดำเนินงานสูงกว่า BBL ในไตรมาสที่ 1 ปี 2021', 'query_generation_time': 36.09971332550049, 'database_fetch_time': 0.0020041465759277344, 'response_generation_time': 56.72564959526062, 'error': None}
# Processing Input 4: เปรียบเทียบผลตอบแทนต่อสินทรัพย์ (ROA) ของบริษัท ADVANC กับ AOT ในปี 2021
# Raw user input: เปรียบเทียบผลตอบแทนต่อสินทรัพย์ (ROA) ของบริษัท ADVANC กับ AOT ในปี 2021
# Error executing query: (mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row
# [SQL: SELECT company.symbol, fr.value FROM financialratios fr JOIN company ON fr.company_id = company.id WHERE fr.type = 'ROA' AND fr.period_id = (SELECT id FROM period WHERE year = 2021) AND company.symbol IN ('ADVANC', 'AOT');]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Comparisons
# Action Input: ADVANC and AOT's ROA in 2021(   symbol  year  value
# 0     AOT  2021  -8.08
# 1  ADVANC  2021  10.40
# 2     AOT  2021  -8.68
# 3  ADVANC  2021  10.41
# 4     AOT  2021  -9.53
# 5  ADVANC  2021  10.82
# 6     AOT  2021  -9.45
# 7  ADVANC  2021  10.91, "SELECT c.symbol, p.year, r.value FROM financialratios r JOIN company c ON r.company_id = c.id JOIN period p ON r.period_id = p.id WHERE p.year = 2021 AND c.symbol IN ('ADVANC', 'AOT') AND r.type = 'ROA';", 38.01125192642212, 0.00957036018371582, None)Final Answer: จากข้อมูลที่ได้มา บริษัท ADVANC มีผลตอบแทนต่อสินทรัพย์ (ROA) สูงกว่าบริษัท AOT ในปี 2021 โดยมีค่าเฉลี่ยเท่ากับ 10.51% สำหรับ ADVANC และ -8.93% สำหรับ AOT ซึ่งแสดงให้เห็นว่าบริษัท ADVANC มีประสิทธิภาพในการใช้สินทรัพย์ในการสร้างรายได้สูงกว่าบริษัท AOT ในปี 2021
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบผลตอบแทนต่อสินทรัพย์ (ROA) ของบริษัท ADVANC กับ AOT ในปี 2021', 'chat_history': [], 'query': "SELECT company.symbol, fr.value FROM financialratios fr JOIN company ON fr.company_id = company.id WHERE fr.type = 'ROA' AND fr.period_id = (SELECT id FROM period WHERE year = 2021) AND company.symbol IN ('ADVANC', 'AOT');", 'query_generation_time': 35.93979287147522, 'database_fetch_time': 0.0, 'sql_error': "(mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row\n[SQL: SELECT company.symbol, fr.value FROM financialratios fr JOIN company ON fr.company_id = company.id WHERE fr.type = 'ROA' AND fr.period_id = (SELECT id FROM period WHERE year = 2021) AND company.symbol IN ('ADVANC', 'AOT');]\n(Background on this error at: https://sqlalche.me/e/20/9h9h)", 'output': 'จากข้อมูลที่ได้มา บริษัท ADVANC มีผลตอบแทนต่อสินทรัพย์ (ROA) สูงกว่าบริษัท AOT ในปี 2021 โดยมีค่าเฉลี่ยเท่ากับ 10.51% สำหรับ ADVANC และ -8.93% สำหรับ AOT ซึ่งแสดงให้เห็นว่าบริษัท ADVANC มีประสิทธิภาพในการใช้สินทรัพย์ในการสร้างรายได้สูงกว่าบริษัท AOT ในปี 2021'}
# Response generation time: 56.46432 seconds
# **response จากข้อมูลที่ได้มา บริษัท ADVANC มีผลตอบแทนต่อสินทรัพย์ (ROA) สูงกว่าบริษัท AOT ในปี 2021 โดยมีค่าเฉลี่ยเท่ากับ 10.51% สำหรับ ADVANC และ -8.93% สำหรับ AOT ซึ่งแสดงให้เห็นว่าบริษัท ADVANC มีประสิทธิภาพในการใช้สินทรัพย์ในการสร้างรายได้สูงกว่าบริษัท AOT ในปี 2021
# **metadata {'query': "SELECT company.symbol, fr.value FROM financialratios fr JOIN company ON fr.company_id = company.id WHERE fr.type = 'ROA' AND fr.period_id = (SELECT id FROM period WHERE year = 2021) AND company.symbol IN ('ADVANC', 'AOT');", 'response': 'จากข้อมูลที่ได้มา บริษัท ADVANC มีผลตอบแทนต่อสินทรัพย์ (ROA) สูงกว่าบริษัท AOT ในปี 2021 โดยมีค่าเฉลี่ยเท่ากับ 10.51% สำหรับ ADVANC และ -8.93% สำหรับ AOT ซึ่งแสดงให้เห็นว่าบริษัท ADVANC มีประสิทธิภาพในการใช้สินทรัพย์ในการสร้างรายได้สูงกว่าบริษัท AOT ในปี 2021', 'query_generation_time': 35.93979287147522, 'database_fetch_time': 0.0, 'response_generation_time': 56.46431517601013, 'error': "(mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row\n[SQL: SELECT company.symbol, fr.value FROM financialratios fr JOIN company ON fr.company_id = company.id WHERE fr.type = 'ROA' AND fr.period_id = (SELECT id FROM period WHERE year = 2021) AND company.symbol IN ('ADVANC', 'AOT');]\n(Background on this error at: https://sqlalche.me/e/20/9h9h)"}
# Processing Input 5: เปรียบเทียบผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 กับปี 2022
# Raw user input: เปรียบเทียบผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 กับปี 2022
# Error executing query: (mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row
# [SQL: SELECT value FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2019), (SELECT id FROM period WHERE year = 2022)) AND type = 'ROE';]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: ADVANC 2019, ADVANC 2022(   id  symbol                                            name
# 0   1  ADVANC  บริษัท แอดวานซ์ อินโฟร์ เซอร์วิส จำกัด (มหาชน), "SELECT * FROM company WHERE symbol IN ('ADVANC');", 33.23854398727417, 0.0, None)Thought: Let's analyze the observed data
# Action: Financial Analysis
# Action Input: ADVANC 2019, ADVANC 2022(   year  quarter total_revenue_quarter net_profit_quarter roe_ratio
# 0  2019        1           43516543.00         7570026.00     55.99
# 1  2019        2           44243026.00         7754154.00     48.22
# 2  2019        3           44895976.00         8800454.00     54.98
# 3  2019        4           49084639.65         7064937.69     49.20
# 4  2022        1           45488146.00         6310839.00     36.14
# 5  2022        2           45553736.00         6305150.00     32.15
# 6  2022        3           46341901.00         6032001.00     33.39
# 7  2022        4           48759130.63         7363294.41     31.08, "SELECT p.year, p.quarter, f.total_revenue_quarter, f.net_profit_quarter, r.value AS roe_ratio FROM financialmetrics f JOIN company c ON f.company_id = c.id JOIN period p ON f.period_id = p.id JOIN financialratios r ON f.company_id = r.company_id AND f.period_id = r.period_id WHERE c.symbol = 'ADVANC' AND p.year IN (2019, 2022) AND r.type = 'ROE' ORDER BY p.year, p.quarter;", 39.32041692733765, 0.006994485855102539, None)Thought: Let's analyze the observed data
# Final Answer: ผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 คือ 49.59% ส่วนในปี 2022 คือ 32.94% ซึ่งแสดงว่าผลตอบแทนต่อผู้ถือหุ้นของบริษัท ADVANC ในปี 2022 ต่ำกว่าปี 2019 ประมาณ 16.65%
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 กับปี 2022', 'chat_history': [], 'query': "SELECT value FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2019), (SELECT id FROM period WHERE year = 2022)) AND type = 'ROE';", 'query_generation_time': 36.268165826797485, 'database_fetch_time': 0.0, 'sql_error': "(mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row\n[SQL: SELECT value FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2019), (SELECT id FROM period WHERE year = 2022)) AND type = 'ROE';]\n(Background on this error at: https://sqlalche.me/e/20/9h9h)", 'output': 'ผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 คือ 49.59% ส่วนในปี 2022 คือ 32.94% ซึ่งแสดงว่าผลตอบแทนต่อผู้ถือหุ้นของบริษัท ADVANC ในปี 2022 ต่ำกว่าปี 2019 ประมาณ 16.65%'}
# Response generation time: 103.67435 seconds
# **response ผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 คือ 49.59% ส่วนในปี 2022 คือ 32.94% ซึ่งแสดงว่าผลตอบแทนต่อผู้ถือหุ้นของบริษัท ADVANC ในปี 2022 ต่ำกว่าปี 2019 ประมาณ 16.65%
# **metadata {'query': "SELECT value FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2019), (SELECT id FROM period WHERE year = 2022)) AND type = 'ROE';", 'response': 'ผลตอบแทนต่อผู้ถือหุ้น (ROE) ของบริษัท ADVANC ในปี 2019 คือ 49.59% ส่วนในปี 2022 คือ 32.94% ซึ่งแสดงว่าผลตอบแทนต่อผู้ถือหุ้นของบริษัท ADVANC ในปี 2022 ต่ำกว่าปี 2019 ประมาณ 16.65%', 'query_generation_time': 36.268165826797485, 'database_fetch_time': 0.0, 'response_generation_time': 103.67434597015381, 'error': "(mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row\n[SQL: SELECT value FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2019), (SELECT id FROM period WHERE year = 2022)) AND type = 'ROE';]\n(Background on this error at: https://sqlalche.me/e/20/9h9h)"}
# Processing Input 6: เปรียบเทียบราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 กับวันที่ 4 กันยายน 2023
# Raw user input: เปรียบเทียบราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 กับวันที่ 4 กันยายน 2023
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Market Prices & Info
# Action Input: ADVANC(   id  symbol                                            name
# 0   1  ADVANC  บริษัท แอดวานซ์ อินโฟร์ เซอร์วิส จำกัด (มหาชน), "SELECT * FROM company WHERE symbol = 'ADVANC';", 32.659990072250366, 0.0, None)Thought: Since we need to compare the closing prices of ADVANC on September 1, 2023, and September 4, 2023, we need to use the Market Prices & Info tool again to retrieve the data for the specific dates.
#
# Action: Market Prices & Info
# Action Input: ADVANC, September 1, 2023; ADVANC, September 4, 2023(   id  company_id  period_id   prior    open    high     low   close average  \
# 0   1           1         21  216.00  216.00  217.00  214.00  215.00  215.22
# 1  51           1         22  215.00  214.00  215.00  212.00  213.00  213.29
#
#    aom_volume     aom_value tr_volume tr_value total_volume   total_value
# 0  3494800.00  752139600.00      0.00     0.00   3496605.00  752528997.00
# 1  4372800.00  932659500.00      0.00     0.00   4376820.00  933518115.00  , "SELECT * FROM marketdata WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE date = '2023-09-01'), (SELECT id FROM period WHERE date = '2023-09-04'));", 35.140175342559814, 0.00404810905456543, None)Thought: No
# Final Answer: ราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 คือ 215.00 บาท ขณะที่ในวันที่ 4 กันยายน 2023 คือ 213.00 บาท
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 กับวันที่ 4 กันยายน 2023', 'chat_history': [], 'query': "SELECT close FROM marketdata WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE date = '2023-09-01') UNION SELECT close FROM marketdata WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE date = '2023-09-04');", 'query_generation_time': 34.76961278915405, 'database_fetch_time': 0.006905317306518555, 'sql_error': None, 'output': 'ราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 คือ 215.00 บาท ขณะที่ในวันที่ 4 กันยายน 2023 คือ 213.00 บาท'}
# Response generation time: 98.81834 seconds
# **response ราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 คือ 215.00 บาท ขณะที่ในวันที่ 4 กันยายน 2023 คือ 213.00 บาท
# **metadata {'query': "SELECT close FROM marketdata WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE date = '2023-09-01') UNION SELECT close FROM marketdata WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE date = '2023-09-04');", 'response': 'ราคาปิดของหุ้น ADVANC ในวันที่ 1 กันยายน 2023 คือ 215.00 บาท ขณะที่ในวันที่ 4 กันยายน 2023 คือ 213.00 บาท', 'query_generation_time': 34.76961278915405, 'database_fetch_time': 0.006905317306518555, 'response_generation_time': 98.81834197044373, 'error': None}
# Processing Input 7: เปรียบเทียบอัตราส่วน PE ของหุ้น ADVANC กับหุ้น CPALL ในวันที่ 1 กันยายน 2023
# Raw user input: เปรียบเทียบอัตราส่วน PE ของหุ้น ADVANC กับหุ้น CPALL ในวันที่ 1 กันยายน 2023
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Market Prices & Info
# Action Input: ADVANC, CPALL, 1 September 2023(   id  company_id  period_id   prior    open    high     low   close average  \
# 0   1           1         21  216.00  216.00  217.00  214.00  215.00  215.22
# 1  14          13         21   65.25   65.50   65.50   65.00   65.25   65.22
#
#     aom_volume     aom_value tr_volume tr_value total_volume   total_value
# 0   3494800.00  752139600.00      0.00     0.00   3496605.00  752528997.00
# 1  13639300.00  889597225.00      0.00     0.00  13641053.00  889711515.75  , "SELECT * FROM marketdata WHERE company_id IN ((SELECT id FROM company WHERE symbol = 'ADVANC'), (SELECT id FROM company WHERE symbol = 'CPALL')) AND period_id = (SELECT id FROM period WHERE date = '2023-09-01');", 31.88829731941223, 0.003025054931640625, None)Thought: Is it necessary to use a tool? No
# Final Answer: อัตราส่วน PE ของหุ้น ADVANC คือ 31.89 และหุ้น CPALL คือ 0.00303 ซึ่งแสดงว่าหุ้น ADVANC มีอัตราส่วน PE สูงกว่าหุ้น CPALL ในวันที่ 1 กันยายน 2023
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบอัตราส่วน PE ของหุ้น ADVANC กับหุ้น CPALL ในวันที่ 1 กันยายน 2023', 'chat_history': [], 'query': "SELECT fr1.value AS ADVANC_PE, fr2.value AS CPALL_PE FROM financialratios fr1, financialratios fr2 WHERE fr1.company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND fr2.company_id = (SELECT id FROM company WHERE symbol = 'CPALL') AND fr1.period_id = (SELECT id FROM period WHERE date = '2023-09-01') AND fr2.period_id = (SELECT id FROM period WHERE date = '2023-09-01') AND fr1.type = 'PE' AND fr2.type = 'PE';", 'query_generation_time': 36.096656799316406, 'database_fetch_time': 0.00754547119140625, 'sql_error': None, 'output': 'อัตราส่วน PE ของหุ้น ADVANC คือ 31.89 และหุ้น CPALL คือ 0.00303 ซึ่งแสดงว่าหุ้น ADVANC มีอัตราส่วน PE สูงกว่าหุ้น CPALL ในวันที่ 1 กันยายน 2023'}
# Response generation time: 52.70834 seconds
# **response อัตราส่วน PE ของหุ้น ADVANC คือ 31.89 และหุ้น CPALL คือ 0.00303 ซึ่งแสดงว่าหุ้น ADVANC มีอัตราส่วน PE สูงกว่าหุ้น CPALL ในวันที่ 1 กันยายน 2023
# **metadata {'query': "SELECT fr1.value AS ADVANC_PE, fr2.value AS CPALL_PE FROM financialratios fr1, financialratios fr2 WHERE fr1.company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND fr2.company_id = (SELECT id FROM company WHERE symbol = 'CPALL') AND fr1.period_id = (SELECT id FROM period WHERE date = '2023-09-01') AND fr2.period_id = (SELECT id FROM period WHERE date = '2023-09-01') AND fr1.type = 'PE' AND fr2.type = 'PE';", 'response': 'อัตราส่วน PE ของหุ้น ADVANC คือ 31.89 และหุ้น CPALL คือ 0.00303 ซึ่งแสดงว่าหุ้น ADVANC มีอัตราส่วน PE สูงกว่าหุ้น CPALL ในวันที่ 1 กันยายน 2023', 'query_generation_time': 36.096656799316406, 'database_fetch_time': 0.00754547119140625, 'response_generation_time': 52.70833897590637, 'error': None}
# Processing Input 8: เปรียบเทียบมูลค่าตลาดของบริษัท ADVANC กับ AOT ในวันที่ 1 กันยายน 2023
# Raw user input: เปรียบเทียบมูลค่าตลาดของบริษัท ADVANC กับ AOT ในวันที่ 1 กันยายน 2023
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Market Prices & Info
# Action Input: ADVANC, AOT, 1 September 2023(   id  company_id  period_id   prior    open    high     low   close average  \
# 0   1           1         21  216.00  216.00  217.00  214.00  215.00  215.22
# 1   2           2         21   72.50   72.75   73.00   72.25   72.75   72.64
#
#     aom_volume     aom_value tr_volume tr_value total_volume   total_value
# 0   3494800.00  752139600.00      0.00     0.00   3496605.00  752528997.00
# 1  13648700.00  991397250.00      0.00     0.00  13649846.00  991480463.25  , "SELECT * FROM marketdata WHERE company_id IN ((SELECT id FROM company WHERE symbol = 'ADVANC'), (SELECT id FROM company WHERE symbol = 'AOT')) AND period_id = (SELECT id FROM period WHERE date = '2023-09-01');", 33.82134032249451, 0.0, None)Final Answer: ณ วันที่ 1 กันยายน 2023 มูลค่าตลาดของบริษัท ADVANC อยู่ที่ 752,528,997 บาท ในขณะที่มูลค่าตลาดของบริษัท AOT อยู่ที่ 991,480,463 บาท โดยมูลค่าตลาดของ AOT สูงกว่ามูลค่าตลาดของ ADVANC ถึงประมาณ 238,951,466 บาท หรือคิดเป็นร้อยละ 31.81
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบมูลค่าตลาดของบริษัท ADVANC กับ AOT ในวันที่ 1 กันยายน 2023', 'chat_history': [], 'query': "SELECT m1.close, m2.close FROM marketdata m1, marketdata m2 WHERE m1.company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND m2.company_id = (SELECT id FROM company WHERE symbol = 'AOT') AND m1.period_id = m2.period_id AND m1.period_id = (SELECT id FROM period WHERE date = '2023-09-01');", 'query_generation_time': 36.152416944503784, 'database_fetch_time': 0.013415813446044922, 'sql_error': None, 'output': 'ณ วันที่ 1 กันยายน 2023 มูลค่าตลาดของบริษัท ADVANC อยู่ที่ 752,528,997 บาท ในขณะที่มูลค่าตลาดของบริษัท AOT อยู่ที่ 991,480,463 บาท โดยมูลค่าตลาดของ AOT สูงกว่ามูลค่าตลาดของ ADVANC ถึงประมาณ 238,951,466 บาท หรือคิดเป็นร้อยละ 31.81'}
# Response generation time: 52.33589 seconds
# **response ณ วันที่ 1 กันยายน 2023 มูลค่าตลาดของบริษัท ADVANC อยู่ที่ 752,528,997 บาท ในขณะที่มูลค่าตลาดของบริษัท AOT อยู่ที่ 991,480,463 บาท โดยมูลค่าตลาดของ AOT สูงกว่ามูลค่าตลาดของ ADVANC ถึงประมาณ 238,951,466 บาท หรือคิดเป็นร้อยละ 31.81
# **metadata {'query': "SELECT m1.close, m2.close FROM marketdata m1, marketdata m2 WHERE m1.company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND m2.company_id = (SELECT id FROM company WHERE symbol = 'AOT') AND m1.period_id = m2.period_id AND m1.period_id = (SELECT id FROM period WHERE date = '2023-09-01');", 'response': 'ณ วันที่ 1 กันยายน 2023 มูลค่าตลาดของบริษัท ADVANC อยู่ที่ 752,528,997 บาท ในขณะที่มูลค่าตลาดของบริษัท AOT อยู่ที่ 991,480,463 บาท โดยมูลค่าตลาดของ AOT สูงกว่ามูลค่าตลาดของ ADVANC ถึงประมาณ 238,951,466 บาท หรือคิดเป็นร้อยละ 31.81', 'query_generation_time': 36.152416944503784, 'database_fetch_time': 0.013415813446044922, 'response_generation_time': 52.335888624191284, 'error': None}
# Processing Input 9: เปรียบเทียบสินทรัพย์รวมของบริษัท BBL กับบริษัท AOT ในปี 2020
# Raw user input: เปรียบเทียบสินทรัพย์รวมของบริษัท BBL กับบริษัท AOT ในปี 2020
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: BBL, AOT, 2020(  symbol  year  quarter   total_assets
# 0    AOT  2020        1   185978838.24
# 1    AOT  2020        2   178076696.56
# 2    AOT  2020        3   173558571.00
# 3    AOT  2020        4   207613192.32
# 4    BBL  2020        1  3395290082.00
# 5    BBL  2020        2  3806363317.00
# 6    BBL  2020        3  3810590601.00
# 7    BBL  2020        4  3822959685.00, "SELECT company.symbol, period.year, period.quarter, financialmetrics.total_assets FROM financialmetrics JOIN company ON financialmetrics.company_id = company.id JOIN period ON financialmetrics.period_id = period.id WHERE company.symbol IN ('BBL', 'AOT') AND period.year = 2020;", 35.49923014640808, 0.0, None)Thought: Is it necessary to use a tool? No
# Final Answer: สินทรัพย์รวมของบริษัท BBL ในปี 2020 คือ 3,395,290,082,000 บาท ในไตรมาสที่ 1, 3,806,363,317,000 บาท ในไตรมาสที่ 2, 3,810,590,601,000 บาท ในไตรมาสที่ 3 และ 3,822,959,685,000 บาท ในไตรมาสที่ 4 ส่วนสินทรัพย์รวมของบริษัท AOT ในปี 2020 คือ 185,978,838,240 บาท ในไตรมาสที่ 1, 178,076,696,560 บาท ในไตรมาสที่ 2, 173,558,571,000 บาท ในไตรมาสที่ 3 และ 207,613,192,320 บาท ในไตรมาสที่ 4
#
# บริษัท BBL มีสินทรัพย์รวมสูงกว่าบริษัท AOT ในทุกไตรมาสของปี 2020
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบสินทรัพย์รวมของบริษัท BBL กับบริษัท AOT ในปี 2020', 'chat_history': [], 'query': "SELECT 'BBL' AS company, bbl.total_assets AS BBL_total_assets, 'AOT' AS company, aot.total_assets AS AOT_total_assets FROM (SELECT total_assets FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'BBL') AND period_id IN (SELECT id FROM period WHERE year = 2020)) bbl, (SELECT total_assets FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'AOT') AND period_id IN (SELECT id FROM period WHERE year = 2020)) aot;", 'query_generation_time': 36.032875061035156, 'database_fetch_time': 0.0, 'sql_error': None, 'output': 'สินทรัพย์รวมของบริษัท BBL ในปี 2020 คือ 3,395,290,082,000 บาท ในไตรมาสที่ 1, 3,806,363,317,000 บาท ในไตรมาสที่ 2, 3,810,590,601,000 บาท ในไตรมาสที่ 3 และ 3,822,959,685,000 บาท ในไตรมาสที่ 4 ส่วนสินทรัพย์รวมของบริษัท AOT ในปี 2020 คือ 185,978,838,240 บาท ในไตรมาสที่ 1, 178,076,696,560 บาท ในไตรมาสที่ 2, 173,558,571,000 บาท ในไตรมาสที่ 3 และ 207,613,192,320 บาท ในไตรมาสที่ 4 \n\nบริษัท BBL มีสินทรัพย์รวมสูงกว่าบริษัท AOT ในทุกไตรมาสของปี 2020'}
# Response generation time: 55.30928 seconds
# **response สินทรัพย์รวมของบริษัท BBL ในปี 2020 คือ 3,395,290,082,000 บาท ในไตรมาสที่ 1, 3,806,363,317,000 บาท ในไตรมาสที่ 2, 3,810,590,601,000 บาท ในไตรมาสที่ 3 และ 3,822,959,685,000 บาท ในไตรมาสที่ 4 ส่วนสินทรัพย์รวมของบริษัท AOT ในปี 2020 คือ 185,978,838,240 บาท ในไตรมาสที่ 1, 178,076,696,560 บาท ในไตรมาสที่ 2, 173,558,571,000 บาท ในไตรมาสที่ 3 และ 207,613,192,320 บาท ในไตรมาสที่ 4
#
# บริษัท BBL มีสินทรัพย์รวมสูงกว่าบริษัท AOT ในทุกไตรมาสของปี 2020
# **metadata {'query': "SELECT 'BBL' AS company, bbl.total_assets AS BBL_total_assets, 'AOT' AS company, aot.total_assets AS AOT_total_assets FROM (SELECT total_assets FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'BBL') AND period_id IN (SELECT id FROM period WHERE year = 2020)) bbl, (SELECT total_assets FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'AOT') AND period_id IN (SELECT id FROM period WHERE year = 2020)) aot;", 'response': 'สินทรัพย์รวมของบริษัท BBL ในปี 2020 คือ 3,395,290,082,000 บาท ในไตรมาสที่ 1, 3,806,363,317,000 บาท ในไตรมาสที่ 2, 3,810,590,601,000 บาท ในไตรมาสที่ 3 และ 3,822,959,685,000 บาท ในไตรมาสที่ 4 ส่วนสินทรัพย์รวมของบริษัท AOT ในปี 2020 คือ 185,978,838,240 บาท ในไตรมาสที่ 1, 178,076,696,560 บาท ในไตรมาสที่ 2, 173,558,571,000 บาท ในไตรมาสที่ 3 และ 207,613,192,320 บาท ในไตรมาสที่ 4 \n\nบริษัท BBL มีสินทรัพย์รวมสูงกว่าบริษัท AOT ในทุกไตรมาสของปี 2020', 'query_generation_time': 36.032875061035156, 'database_fetch_time': 0.0, 'response_generation_time': 55.3092839717865, 'error': None}
# Processing Input 10: เปรียบเทียบกระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 กับไตรมาสที่ 4 ปี 2021
# Raw user input: เปรียบเทียบกระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 กับไตรมาสที่ 4 ปี 2021
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: ADVANC, Q3 2021, Q4 2021(    id  company_id  period_id  total_assets total_liabilities  \
# 0  430           1         11  356520803.00      281677931.00
# 1  476           1         12  356221742.94      274397220.56
#
#   paidup_share_capital shareholder_equity total_equity total_revenue_quarter  \
# 0           2973926.00        74717796.00  74842872.00           42555359.00
# 1           2973925.79        81698752.33  81824522.38           50585431.36
#
#   total_revenue_accum  ... total_expenses_accum ebit_quarter   ebit_accum  \
# 0        132020104.00  ...         102324570.00   9187784.00  28767435.00
# 1        182605535.36  ...         143299130.95   9752648.63  38520083.63
#
#   net_profit_quarter net_profit_accum eps_quarter eps_accum  \
# 0         6374062.00      20058768.00        2.14      6.75
# 1         6863377.66      26922145.66        2.30      9.05
#
#   operating_cash_flow investing_cash_flow financing_cash_flow
# 0         64699327.00        -34278787.00        -37500864.00
# 1         86634044.46        -45351937.25        -46963170.46
#
# [2 rows x 21 columns], "SELECT * FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id IN ((SELECT id FROM period WHERE year = 2021 AND quarter = 3), (SELECT id FROM period WHERE year = 2021 AND quarter = 4));", 37.451223611831665, 0.0, None)Thought: Is it necessary to use a tool? No
# Final Answer: จากข้อมูลดังกล่าว สามารถเห็นได้ว่ากระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 เท่ากับ -34,278,787,000 บาท และในไตรมาสที่ 4 ปี 2021 เท่ากับ -45,351,937,250 บาท ผลต่างระหว่างสองไตรมาสคือประมาณ -11,073,150,250 บาท ซึ่งเป็นผลลบ หมายความว่าบริษัทมีการใช้เงินลงทุนเพิ่มขึ้นในไตรมาสที่ 4 ปี 2021
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบกระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 กับไตรมาสที่ 4 ปี 2021', 'chat_history': [], 'query': "SELECT investing_cash_flow FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 3) UNION ALL SELECT investing_cash_flow FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 4);", 'query_generation_time': 37.8910391330719, 'database_fetch_time': 0.0, 'sql_error': None, 'output': 'จากข้อมูลดังกล่าว สามารถเห็นได้ว่ากระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 เท่ากับ -34,278,787,000 บาท และในไตรมาสที่ 4 ปี 2021 เท่ากับ -45,351,937,250 บาท ผลต่างระหว่างสองไตรมาสคือประมาณ -11,073,150,250 บาท ซึ่งเป็นผลลบ หมายความว่าบริษัทมีการใช้เงินลงทุนเพิ่มขึ้นในไตรมาสที่ 4 ปี 2021'}
# Response generation time: 58.40320 seconds
# **response จากข้อมูลดังกล่าว สามารถเห็นได้ว่ากระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 เท่ากับ -34,278,787,000 บาท และในไตรมาสที่ 4 ปี 2021 เท่ากับ -45,351,937,250 บาท ผลต่างระหว่างสองไตรมาสคือประมาณ -11,073,150,250 บาท ซึ่งเป็นผลลบ หมายความว่าบริษัทมีการใช้เงินลงทุนเพิ่มขึ้นในไตรมาสที่ 4 ปี 2021
# **metadata {'query': "SELECT investing_cash_flow FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 3) UNION ALL SELECT investing_cash_flow FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE year = 2021 AND quarter = 4);", 'response': 'จากข้อมูลดังกล่าว สามารถเห็นได้ว่ากระแสเงินสดจากการลงทุนของบริษัท ADVANC ในไตรมาสที่ 3 ปี 2021 เท่ากับ -34,278,787,000 บาท และในไตรมาสที่ 4 ปี 2021 เท่ากับ -45,351,937,250 บาท ผลต่างระหว่างสองไตรมาสคือประมาณ -11,073,150,250 บาท ซึ่งเป็นผลลบ หมายความว่าบริษัทมีการใช้เงินลงทุนเพิ่มขึ้นในไตรมาสที่ 4 ปี 2021', 'query_generation_time': 37.8910391330719, 'database_fetch_time': 0.0, 'response_generation_time': 58.4031982421875, 'error': None}
# Processing Input 11: เปรียบเทียบกำไรต่อหุ้น (EPS) ของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2020
# Raw user input: เปรียบเทียบกำไรต่อหุ้น (EPS) ของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2020
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: ADVANC and BBL, Q1 2020Error executing query: (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'Please provide the specific question you want to ask about ADVANC and BBL in Q1 ' at line 1
# [SQL: Please provide the specific question you want to ask about ADVANC and BBL in Q1 2020. For example, do you want to know their total assets, net profit margin, or something else?]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# (Empty DataFrame
# Columns: []
# Index: [], 'Please provide the specific question you want to ask about ADVANC and BBL in Q1 2020. For example, do you want to know their total assets, net profit margin, or something else?', 35.1415536403656, 0.0, "(mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'Please provide the specific question you want to ask about ADVANC and BBL in Q1 ' at line 1\n[SQL: Please provide the specific question you want to ask about ADVANC and BBL in Q1 2020. For example, do you want to know their total assets, net profit margin, or something else?]\n(Background on this error at: https://sqlalche.me/e/20/f405)")Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: ADVANC and BBL, Q1 2020, EPS(   symbol eps_quarter
# 0  ADVANC        2.27
# 1     BBL        4.02, "SELECT company.symbol, fm.eps_quarter FROM financialmetrics fm JOIN company ON fm.company_id = company.id WHERE fm.period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 1) AND company.symbol IN ('ADVANC', 'BBL');", 34.93593955039978, 0.01590561866760254, None)Final Answer: กำไรต่อหุ้น (EPS) ของบริษัท ADVANC ในไตรมาสที่ 1 ปี 2020 อยู่ที่ 2.27 บาท ส่วนของบริษัท BBL อยู่ที่ 4.02 บาท
#
# > Finished chain.
# Agent response: {'input': 'เปรียบเทียบกำไรต่อหุ้น (EPS) ของบริษัท ADVANC กับ BBL ในไตรมาสที่ 1 ปี 2020', 'chat_history': [], 'query': "SELECT 'ADVANC' AS company, eps_quarter AS eps FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 1) UNION SELECT 'BBL' AS company, eps_quarter AS eps FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'BBL') AND period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 1);", 'query_generation_time': 37.023452281951904, 'database_fetch_time': 0.0, 'sql_error': None, 'output': 'กำไรต่อหุ้น (EPS) ของบริษัท ADVANC ในไตรมาสที่ 1 ปี 2020 อยู่ที่ 2.27 บาท ส่วนของบริษัท BBL อยู่ที่ 4.02 บาท'}
# Response generation time: 100.61663 seconds
# **response กำไรต่อหุ้น (EPS) ของบริษัท ADVANC ในไตรมาสที่ 1 ปี 2020 อยู่ที่ 2.27 บาท ส่วนของบริษัท BBL อยู่ที่ 4.02 บาท
# **metadata {'query': "SELECT 'ADVANC' AS company, eps_quarter AS eps FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 1) UNION SELECT 'BBL' AS company, eps_quarter AS eps FROM financialmetrics WHERE company_id = (SELECT id FROM company WHERE symbol = 'BBL') AND period_id = (SELECT id FROM period WHERE year = 2020 AND quarter = 1);", 'response': 'กำไรต่อหุ้น (EPS) ของบริษัท ADVANC ในไตรมาสที่ 1 ปี 2020 อยู่ที่ 2.27 บาท ส่วนของบริษัท BBL อยู่ที่ 4.02 บาท', 'query_generation_time': 37.023452281951904, 'database_fetch_time': 0.0, 'response_generation_time': 100.6166262626648, 'error': None}
# Processing Input 12: เปรียบเทียบอัตราหนี้สินต่อทุน (DE) ของบริษัท ADVANC กับ CPALL ในปี 2020
# Raw user input: เปรียบเทียบอัตราหนี้สินต่อทุน (DE) ของบริษัท ADVANC กับ CPALL ในปี 2020
# Error executing query: (mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row
# [SQL: SELECT 'ADVANC' AS company, value AS DE_ADVANC, (SELECT value FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'CPALL') AND period_id = (SELECT id FROM period WHERE year = 2020) AND type = 'DE') AS DE_CPALL FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'ADVANC') AND period_id = (SELECT id FROM period WHERE year = 2020) AND type = 'DE';]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: Retrieve debt-to-equity (D/E) ratio for ADVANC and CPALL in 2020Error executing query: (mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row
# [SQL: SELECT value FROM financialratios WHERE company_id IN ((SELECT id FROM company WHERE symbol IN ('ADVANC', 'CPALL'))) AND period_id = (SELECT id FROM period WHERE year = 2020) AND type = 'DE';]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# (Empty DataFrame
# Columns: []
# Index: [], "SELECT value FROM financialratios WHERE company_id IN ((SELECT id FROM company WHERE symbol IN ('ADVANC', 'CPALL'))) AND period_id = (SELECT id FROM period WHERE year = 2020) AND type = 'DE';", 36.94556403160095, 0.0, "(mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row\n[SQL: SELECT value FROM financialratios WHERE company_id IN ((SELECT id FROM company WHERE symbol IN ('ADVANC', 'CPALL'))) AND period_id = (SELECT id FROM period WHERE year = 2020) AND type = 'DE';]\n(Background on this error at: https://sqlalche.me/e/20/9h9h)")Thought: It seems like the previous attempt to retrieve the debt-to-equity (D/E) ratio failed. Let's try again with a different approach.
#
# Action: Financial Statements
# Action Input: Retrieve financial statements for ADVANC and CPALL in 2020, specifically focusing on total liabilities and shareholder equity.Error executing query: (mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row
# [SQL: SELECT fm.company_id, c.symbol, fm.total_liabilities, fm.shareholder_equity FROM financialmetrics fm JOIN company c ON fm.company_id = c.id WHERE c.symbol IN ('ADVANC', 'CPALL') AND fm.period_id = (SELECT id FROM period WHERE year = 2020);]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# (Empty DataFrame
# Columns: []
# Index: [], "SELECT fm.company_id, c.symbol, fm.total_liabilities, fm.shareholder_equity FROM financialmetrics fm JOIN company c ON fm.company_id = c.id WHERE c.symbol IN ('ADVANC', 'CPALL') AND fm.period_id = (SELECT id FROM period WHERE year = 2020);", 34.88572287559509, 0.0, "(mysql.connector.errors.DataError) 1242 (21000): Subquery returns more than 1 row\n[SQL: SELECT fm.company_id, c.symbol, fm.total_liabilities, fm.shareholder_equity FROM financialmetrics fm JOIN company c ON fm.company_id = c.id WHERE c.symbol IN ('ADVANC', 'CPALL') AND fm.period_id = (SELECT id FROM period WHERE year = 2020);]\n(Background on this error at: https://sqlalche.me/e/20/9h9h)")Thought: It seems like the previous attempts to retrieve the debt-to-equity (D/E) ratio failed. Let's try again with a different approach.
#
# Action: Financial Analysis
# Action Input: Calculate the debt-to-equity (D/E) ratio for ADVANC and CPALL in 2020 using total liabilities and shareholder equity.(   year  symbol debt_to_equity_ratio
# 0  2020  ADVANC             4.794676
# 1  2020  ADVANC             4.141166
# 2  2020  ADVANC             4.163097
# 3  2020  ADVANC             3.632434
# 4  2020   CPALL             3.143986
# 5  2020   CPALL             3.690266
# 6  2020   CPALL             3.609836
# 7  2020   CPALL             4.255525, "SELECT p.year, c.symbol, f.total_liabilities / f.shareholder_equity AS debt_to_equity_ratio FROM financialmetrics f JOIN company c ON f.company_id = c.id JOIN period p ON f.period_id = p.id WHERE c.symbol IN ('ADVANC', 'CPALL') AND p.year = 2020;", 39.05057692527771, 0.0, None)Thought: Is it necessary to use a tool? No
# Final Answer: อัตราหนี้สินต่อทุน (DE) ของบริษัท ADVANC ในปี 2020 อยู่ในช่วง 3.63-4.79 ส่วนบริษัท CPALL อยู่ในช่วง 3.14-4.25
#
# > Finished chain.
# ...
# Processing Input 43: อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ส่งผลต่อกำไรจากการดำเนินงานอย่างไร
# Raw user input: อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ส่งผลต่อกำไรจากการดำเนินงานอย่างไร
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: BCP(   id symbol                                      name
# 0   4    BCP  บริษัท บางจาก คอร์ปอเรชั่น จำกัด (มหาชน), "SELECT * FROM company WHERE symbol = 'BCP';", 34.629698276519775, 0.0, None)Thought: Is it necessary to use a tool? Yes
# Action: Financial Analysis
# Action Input: BCP, Asset Turnover Ratio(    year  quarter asset_turnover_ratio
# 0   2019        1                 1.68
# 1   2019        2                 1.69
# 2   2019        3                 1.60
# 3   2019        4                 1.56
# 4   2020        1                 1.44
# 5   2020        2                 1.31
# 6   2020        3                 1.17
# 7   2020        4                 0.99
# 8   2021        1                 0.94
# 9   2021        2                 1.06
# 10  2021        3                 0.99
# 11  2021        4                 1.15
# 12  2022        1                 1.24
# 13  2022        2                 1.42
# 14  2022        3                 1.39
# 15  2022        4                 1.41
# 16  2023        1                 1.42
# 17  2023        2                 1.32
# 18  2023        3                 1.21, "SELECT p.year, p.quarter, r.value AS asset_turnover_ratio FROM financialratios r JOIN financialmetrics f ON r.company_id = f.company_id AND r.period_id = f.period_id JOIN company c ON f.company_id = c.id JOIN period p ON f.period_id = p.id WHERE c.symbol = 'BCP' AND r.type = 'TotalAssetTurnover';", 34.21589946746826, 0.0036842823028564453, None)Final Answer: อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP มีผลต่อกำไรจากการดำเนินงานโดยตรง เนื่องจากอัตราการหมุนเวียนของสินทรัพย์ถาวรแสดงให้เห็นว่าสินทรัพย์ถาวรสามารถสร้างรายได้ได้มากน้อยเพียงใด หากอัตราการหมุนเวียนของสินทรัพย์ถาวรสูงそれはหมายความว่าสินทรัพย์ถาวรสามารถสร้างรายได้ได้มาก และจะส่งผลให้กำไรจากการดำเนินงานสูงขึ้น และ ngượcกลับกัน หากอัตราการหมุนเวียนของสินทรัพย์ถาวรต่ำそれはหมายความว่าสินทรัพย์ถาวรไม่สามารถสร้างรายได้ได้มาก และจะส่งผลให้กำไรจากการดำเนินงานต่ำลง โดยอัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ในช่วงเวลาที่ผ่านมาอยู่ในช่วงประมาณ 0.94-1.69 ซึ่งเป็นช่วงกลางๆ ของอุตสาหกรรม ดังนั้น BCP ควรพยายามปรับปรุงอัตราการหมุนเวียนของสินทรัพย์ถาวรเพื่อเพิ่มกำไรจากการดำเนินงาน.
#
# > Finished chain.
# Agent response: {'input': 'อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ส่งผลต่อกำไรจากการดำเนินงานอย่างไร', 'chat_history': [], 'query': "SELECT value FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'BCP') AND period_id = (SELECT id FROM period WHERE year = 2019 AND quarter = 1) AND type = 'FixedAssetTurnover';", 'query_generation_time': 35.922627449035645, 'database_fetch_time': 0.0030035972595214844, 'sql_error': None, 'output': 'อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP มีผลต่อกำไรจากการดำเนินงานโดยตรง เนื่องจากอัตราการหมุนเวียนของสินทรัพย์ถาวรแสดงให้เห็นว่าสินทรัพย์ถาวรสามารถสร้างรายได้ได้มากน้อยเพียงใด หากอัตราการหมุนเวียนของสินทรัพย์ถาวรสูงそれはหมายความว่าสินทรัพย์ถาวรสามารถสร้างรายได้ได้มาก และจะส่งผลให้กำไรจากการดำเนินงานสูงขึ้น และ ngượcกลับกัน หากอัตราการหมุนเวียนของสินทรัพย์ถาวรต่ำそれはหมายความว่าสินทรัพย์ถาวรไม่สามารถสร้างรายได้ได้มาก และจะส่งผลให้กำไรจากการดำเนินงานต่ำลง โดยอัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ในช่วงเวลาที่ผ่านมาอยู่ในช่วงประมาณ 0.94-1.69 ซึ่งเป็นช่วงกลางๆ ของอุตสาหกรรม ดังนั้น BCP ควรพยายามปรับปรุงอัตราการหมุนเวียนของสินทรัพย์ถาวรเพื่อเพิ่มกำไรจากการดำเนินงาน.'}
# Response generation time: 104.12044 seconds
# **response อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP มีผลต่อกำไรจากการดำเนินงานโดยตรง เนื่องจากอัตราการหมุนเวียนของสินทรัพย์ถาวรแสดงให้เห็นว่าสินทรัพย์ถาวรสามารถสร้างรายได้ได้มากน้อยเพียงใด หากอัตราการหมุนเวียนของสินทรัพย์ถาวรสูงそれはหมายความว่าสินทรัพย์ถาวรสามารถสร้างรายได้ได้มาก และจะส่งผลให้กำไรจากการดำเนินงานสูงขึ้น และ ngượcกลับกัน หากอัตราการหมุนเวียนของสินทรัพย์ถาวรต่ำそれはหมายความว่าสินทรัพย์ถาวรไม่สามารถสร้างรายได้ได้มาก และจะส่งผลให้กำไรจากการดำเนินงานต่ำลง โดยอัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ในช่วงเวลาที่ผ่านมาอยู่ในช่วงประมาณ 0.94-1.69 ซึ่งเป็นช่วงกลางๆ ของอุตสาหกรรม ดังนั้น BCP ควรพยายามปรับปรุงอัตราการหมุนเวียนของสินทรัพย์ถาวรเพื่อเพิ่มกำไรจากการดำเนินงาน.
# **metadata {'query': "SELECT value FROM financialratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'BCP') AND period_id = (SELECT id FROM period WHERE year = 2019 AND quarter = 1) AND type = 'FixedAssetTurnover';", 'response': 'อัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP มีผลต่อกำไรจากการดำเนินงานโดยตรง เนื่องจากอัตราการหมุนเวียนของสินทรัพย์ถาวรแสดงให้เห็นว่าสินทรัพย์ถาวรสามารถสร้างรายได้ได้มากน้อยเพียงใด หากอัตราการหมุนเวียนของสินทรัพย์ถาวรสูงそれはหมายความว่าสินทรัพย์ถาวรสามารถสร้างรายได้ได้มาก และจะส่งผลให้กำไรจากการดำเนินงานสูงขึ้น และ ngượcกลับกัน หากอัตราการหมุนเวียนของสินทรัพย์ถาวรต่ำそれはหมายความว่าสินทรัพย์ถาวรไม่สามารถสร้างรายได้ได้มาก และจะส่งผลให้กำไรจากการดำเนินงานต่ำลง โดยอัตราการหมุนเวียนของสินทรัพย์ถาวรของ BCP ในช่วงเวลาที่ผ่านมาอยู่ในช่วงประมาณ 0.94-1.69 ซึ่งเป็นช่วงกลางๆ ของอุตสาหกรรม ดังนั้น BCP ควรพยายามปรับปรุงอัตราการหมุนเวียนของสินทรัพย์ถาวรเพื่อเพิ่มกำไรจากการดำเนินงาน.', 'query_generation_time': 35.922627449035645, 'database_fetch_time': 0.0030035972595214844, 'response_generation_time': 104.12044405937195, 'error': None}
# Processing Input 44: การเปลี่ยนแปลงของ P/E Ratio ของ BTS มีผลต่อการประเมินมูลค่าบริษัทอย่างไร
# Raw user input: การเปลี่ยนแปลงของ P/E Ratio ของ BTS มีผลต่อการประเมินมูลค่าบริษัทอย่างไร
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Market Prices & Info
# Action Input: BTS (stock symbol)Error executing query: (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'What would you like to know about BTS (stock symbol)?' at line 1
# [SQL: What would you like to know about BTS (stock symbol)?]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# (Empty DataFrame
# Columns: []
# Index: [], 'What would you like to know about BTS (stock symbol)?', 33.530887603759766, 0.0, "(mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'What would you like to know about BTS (stock symbol)?' at line 1\n[SQL: What would you like to know about BTS (stock symbol)?]\n(Background on this error at: https://sqlalche.me/e/20/f405)")It seems like there's an error in retrieving the market data for BTS. Let me try again.
#
# Thought: Is it necessary to use a tool? Yes
# Action: Market Prices & Info
# Action Input: BTS (stock symbol)Error executing query: (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'Please provide the actual question about BTS stock, and I'll translate it into a' at line 1
# [SQL: Please provide the actual question about BTS stock, and I'll translate it into a MySQL query.]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# (Empty DataFrame
# Columns: []
# Index: [], "Please provide the actual question about BTS stock, and I'll translate it into a MySQL query.", 32.23132252693176, 0.0, "(mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'Please provide the actual question about BTS stock, and I'll translate it into a' at line 1\n[SQL: Please provide the actual question about BTS stock, and I'll translate it into a MySQL query.]\n(Background on this error at: https://sqlalche.me/e/20/f405)")Thought: Is it necessary to use a tool? No
# Final Answer: ฉันขอโทษที่ไม่สามารถแสดงข้อมูล P/E Ratio ของ BTS ได้เนื่องจากมีปัญหาในการเชื่อมต่อกับฐานข้อมูล หากคุณต้องการทราบข้อมูลอื่นๆ ของ BTS โปรดระบุคำถามของคุณ และฉันจะพยายามตอบแทนคุณให้ได้
#
# > Finished chain.
# Agent response: {'input': 'การเปลี่ยนแปลงของ P/E Ratio ของ BTS มีผลต่อการประเมินมูลค่าบริษัทอย่างไร', 'chat_history': [], 'query': "SELECT value FROM marketratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'BTS') AND period_id IN (SELECT id FROM period WHERE year = 2019 AND quarter IN (1, 2, 3, 4)) AND type = 'peRatio' ORDER BY period_id;", 'query_generation_time': 37.79938530921936, 'database_fetch_time': 0.017417430877685547, 'sql_error': None, 'output': 'ฉันขอโทษที่ไม่สามารถแสดงข้อมูล P/E Ratio ของ BTS ได้เนื่องจากมีปัญหาในการเชื่อมต่อกับฐานข้อมูล หากคุณต้องการทราบข้อมูลอื่นๆ ของ BTS โปรดระบุคำถามของคุณ และฉันจะพยายามตอบแทนคุณให้ได้'}
# Response generation time: 95.50911 seconds
# **response ฉันขอโทษที่ไม่สามารถแสดงข้อมูล P/E Ratio ของ BTS ได้เนื่องจากมีปัญหาในการเชื่อมต่อกับฐานข้อมูล หากคุณต้องการทราบข้อมูลอื่นๆ ของ BTS โปรดระบุคำถามของคุณ และฉันจะพยายามตอบแทนคุณให้ได้
# **metadata {'query': "SELECT value FROM marketratios WHERE company_id = (SELECT id FROM company WHERE symbol = 'BTS') AND period_id IN (SELECT id FROM period WHERE year = 2019 AND quarter IN (1, 2, 3, 4)) AND type = 'peRatio' ORDER BY period_id;", 'response': 'ฉันขอโทษที่ไม่สามารถแสดงข้อมูล P/E Ratio ของ BTS ได้เนื่องจากมีปัญหาในการเชื่อมต่อกับฐานข้อมูล หากคุณต้องการทราบข้อมูลอื่นๆ ของ BTS โปรดระบุคำถามของคุณ และฉันจะพยายามตอบแทนคุณให้ได้', 'query_generation_time': 37.79938530921936, 'database_fetch_time': 0.017417430877685547, 'response_generation_time': 95.50911474227905, 'error': None}
# Processing Input 45: การเติบโตของ ROE ของบริษัท AOT ส่งผลต่อการดึงดูดนักลงทุนอย่างไร
# Raw user input: การเติบโตของ ROE ของบริษัท AOT ส่งผลต่อการดึงดูดนักลงทุนอย่างไร
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: Financial Statements
# Action Input: AOT(   id symbol                                 name
# 0   2    AOT  บริษัท ท่าอากาศยานไทย จำกัด (มหาชน), "SELECT * FROM company WHERE symbol = 'AOT';", 33.30453157424927, 0.0, None)Thought: Is it necessary to use a tool? Yes
# Action: Financial Analysis
# Action Input: AOT(   id symbol                                 name
# 0   2    AOT  บริษัท ท่าอากาศยานไทย จำกัด (มหาชน), "SELECT * FROM company WHERE symbol = 'AOT';", 36.317349910736084, 0.0019485950469970703, None)Error generating response: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jcd3amy8e6dssfntaf2128mj` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500087, Requested 769. Please try again in 2m27.921399999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# **response None
# **metadata {'query': None, 'response': 'Error generating response', 'query_generation_time': None, 'database_fetch_time': None, 'response_generation_time': None, 'error': "Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jcd3amy8e6dssfntaf2128mj` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500087, Requested 769. Please try again in 2m27.921399999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}"}
# Error processing input 45: type NoneType doesn't define __round__ method
# Processing Input 46: การเพิ่มขึ้นของอัตราหนี้สินต่อทุน (DE) ของบริษัท BEM มีผลกระทบต่อความเสี่ยงทางการเงินอย่างไร
# Raw user input: การเพิ่มขึ้นของอัตราหนี้สินต่อทุน (DE) ของบริษัท BEM มีผลกระทบต่อความเสี่ยงทางการเงินอย่างไร
# Error executing query: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jcd3amy8e6dssfntaf2128mj` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500084, Requested 1657. Please try again in 5m0.880799999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
#
#
# > Entering new AgentExecutor chain...
# Error generating response: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jcd3amy8e6dssfntaf2128mj` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500082, Requested 610. Please try again in 1m59.7202s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# **response None
# **metadata {'query': None, 'response': 'Error generating response', 'query_generation_time': None, 'database_fetch_time': None, 'response_generation_time': None, 'error': "Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jcd3amy8e6dssfntaf2128mj` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500082, Requested 610. Please try again in 1m59.7202s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}"}
# Error processing input 46: type NoneType doesn't define __round__ method
# Processing Input 47: ผลตอบแทนต่อสินทรัพย์ (ROA) ของ CPF ส่งผลต่อความสามารถในการใช้สินทรัพย์อย่างไรในปี 2019
# Raw user input: ผลตอบแทนต่อสินทรัพย์ (ROA) ของ CPF ส่งผลต่อความสามารถในการใช้สินทรัพย์อย่างไรในปี 2019
# Error executing query: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jcd3amy8e6dssfntaf2128mj` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500079, Requested 1650. Please try again in 4m58.8872s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
#
#
# > Entering new AgentExecutor chain...
# Error generating response: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jcd3amy8e6dssfntaf2128mj` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500073, Requested 602. Please try again in 1m56.7768s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# **response None
# **metadata {'query': None, 'response': 'Error generating response', 'query_generation_time': None, 'database_fetch_time': None, 'response_generation_time': None, 'error': "Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jcd3amy8e6dssfntaf2128mj` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500073, Requested 602. Please try again in 1m56.7768s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}"}
# Error processing input 47: type NoneType doesn't define __round__ method
# Logs exported to query_logs.csv

# %%
# Reset session state logs to ensure old data is not retained
st.session_state.query_logs = []

# Collect responses
for idx, user_input in enumerate(inputs, start=1):
    print(f"Processing Input {idx}: {user_input}")
    try:
        # Call chatbot logic to get the response, metadata, and error
        response, metadata, error = handle_submit(user_input)
        print("**response",response)
        print("**metadata",metadata)
        # Log the response and metadata
        st.session_state.query_logs.append({
            "Sequence": idx,
            "Question": user_input,
            "Response": response if response else "Error occurred",
            "Query (SQL)": metadata.get("query", ""),
            "Query Generation Time (s)": round(metadata.get("query_generation_time", 0.0), 6),
            "Database Fetch Time (s)": round(metadata.get("database_fetch_time", 0.0), 8),
            "Response Generation Time (s)": round(metadata.get("response_generation_time", 0.0), 6),
            "Total Time (s)": round(
                metadata.get("query_generation_time", 0.0) +
                metadata.get("database_fetch_time", 0.0) +
                metadata.get("response_generation_time", 0.0),
                6
            ),
            "Error": error if error else "",
        })
    except Exception as e:
        print(f"Error processing input {idx}: {e}")
        # Log error if something goes wrong
        st.session_state.query_logs.append({
            "Sequence": idx,
            "Question": user_input,
            "Response": "Error occurred",
            "Query (SQL)": "",
            "Query Generation Time (s)": 0.0,
            "Database Fetch Time (s)": 0.0,
            "Response Generation Time (s)": 0.0,
            "Total Time (s)": 0.0,
            "Error": str(e),
        })

# Export logs to CSV file if there are any logs
if st.session_state.query_logs:
    logs_df = pd.DataFrame(st.session_state.query_logs)
    logs_df.to_csv("test.csv", index=False, encoding="utf-8-sig")
    print("Logs exported to query_logs.csv")
else:
    print("No logs to export.")
# Out:
# Processing Input 1: ขอข้อมูล open ของหุ้น BBL วันที่ 2023-09-01
# Raw user input: ขอข้อมูล open ของหุ้น BBL วันที่ 2023-09-01
#
#
# > Entering new AgentExecutor chain...
# Thought: Is it necessary to use a tool? Yes
# Action: search company's data
# Action Input: BBL open price on 2023-09-01(     open
# 0  169.50, "SELECT open FROM filteredEODData WHERE symbol = 'BBL' AND date = '2023-09-01' LIMIT 1;", 23.92397451400757, 0.001999378204345703, None)Thought: Is it necessary to use a tool? No
# Final Answer: ราคาหุ้น BBL เปิดที่ 169.50 บาทในวันที่ 1 กันยายน 2566
#
# > Finished chain.
# Agent response: {'input': 'ขอข้อมูล open ของหุ้น BBL วันที่ 2023-09-01', 'chat_history': [], 'query': "SELECT open FROM filteredEODData WHERE symbol = 'BBL' AND date = '2023-09-01' LIMIT 1;", 'query_generation_time': 1.568105697631836, 'database_fetch_time': 0.002679109573364258, 'sql_error': None, 'output': 'ราคาหุ้น BBL เปิดที่ 169.50 บาทในวันที่ 1 กันยายน 2566'}
# Response generation time: 32.38189 seconds
# **response ราคาหุ้น BBL เปิดที่ 169.50 บาทในวันที่ 1 กันยายน 2566
# **metadata {'query': "SELECT open FROM filteredEODData WHERE symbol = 'BBL' AND date = '2023-09-01' LIMIT 1;", 'response': 'ราคาหุ้น BBL เปิดที่ 169.50 บาทในวันที่ 1 กันยายน 2566', 'query_generation_time': 1.568105697631836, 'database_fetch_time': 0.002679109573364258, 'response_generation_time': 32.38188576698303, 'error': None}
# Logs exported to query_logs.csv

# %%
logs_df
# Out:
#    Sequence                                           Question  \
# 0        51  เปรียบเทียบสินทรัพย์รวมของบริษัท ADVANC กับบริ...
# 1        52  เปรียบเทียบหนี้สินรวมของบริษัท ADVANC กับบริษั...
#
#                                             Response  \
# 0  จากข้อมูลที่ได้จากการสืบค้นพบว่า สินทรัพย์รวมข...
# 1  จากข้อมูลที่ได้รับมา บริษัท ADVANC มีหนี้สินรว...
#
#                                          Query (SQL)  \
# 0  SELECT symbol, Quarter, totalAssets FROM finan...
# 1  SELECT symbol, Quarter, totalLiabilities FROM ...
#
#    Query Generation Time (s)  Database Fetch Time (s)  \
# 0                   2.444819                 0.002069
# 1                  40.378198                 0.003443
#
#    Response Generation Time (s)  Total Time (s) Error
# 0                     35.509861       37.956748
# 1                     55.343430       95.725071

# %%
# Cleaning process
cleaned_data = []

for i in range(0, len(logs_df)-2, 2):
    query_row = logs_df.iloc[i]
    meta_row = logs_df.iloc[i + 1]
    
    cleaned_data.append({
        "Sequence": meta_row["Sequence"],
        "Question": meta_row["Question"],
        "query": query_row["query"],
        "time": query_row["time"],
        "Response": meta_row["Response"],
        "Error": meta_row["Error"]
    })

cleaned_df = pd.DataFrame(cleaned_data)

cleaned_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 6
#       4 for i in range(0, len(logs_df), 2):
#       5     query_row = logs_df.iloc[i]
# ----> 6     meta_row = logs_df.iloc[i + 1]
#       8     cleaned_data.append({
#       9         "Sequence": meta_row["Sequence"],
#      10         "Question": meta_row["Question"],
#    (...)
#      14         "Error": meta_row["Error"]
#      15     })
#      17 cleaned_df = pd.DataFrame(cleaned_data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1714, in _iLocIndexer._getitem_axis(self, key, axis)
#    1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
# -> 1714 self._validate_integer(key, axis)
#    1716 return self.obj._ixs(key, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1647, in _iLocIndexer._validate_integer(self, key, axis)
#    1645 len_axis = len(self.obj._get_axis(axis))
#    1646 if key >= len_axis or key < -len_axis:
# -> 1647     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
import pandas as pd

# Assuming logs_df is your input DataFrame
# Drop rows where `Sequence` is NaN to remove unnecessary rows
cleaned_df = logs_df.dropna(subset=["Sequence"])

# Keep only relevant columns and rename them
cleaned_df = cleaned_df.rename(columns={
    "Sequence": "Sequence",
    "Question": "Question",
    "query": "query",
    "Response": "Response",
    "time": "time",
    "error": "error"
})

# Fill any remaining NaN values with empty strings or zeros where appropriate
cleaned_df = cleaned_df.fillna({
    "query": "",
    "Response": "",
    "error": "",
    "time": 0.0
})

# Convert the Sequence column to integers
cleaned_df["Sequence"] = cleaned_df["Sequence"].astype(int)

# Reset the index to clean up the DataFrame
cleaned_df = cleaned_df.reset_index(drop=True)

# Save the cleaned DataFrame to a CSV file
cleaned_df.to_csv("cleaned_query_logs.csv", index=False, encoding="utf-8-sig")

# Print the cleaned DataFrame
cleaned_df
# Out:
#   query  time  ram_used  Sequence  \
# 0         0.0       0.0        51
# 1         0.0       0.0        52
# 2         0.0       0.0        53
#
#                                             Question Query        Response  \
# 0  เปรียบเทียบสินทรัพย์รวมของบริษัท ADVANC กับบริ...        Error occurred
# 1  เปรียบเทียบหนี้สินรวมของบริษัท ADVANC กับบริษั...        Error occurred
# 2  เปรียบเทียบรายได้รวมในไตรมาสของบริษัท ADVANC ก...        Error occurred
#
#    Time  RAM_Used                                  Error
# 0   0.0       0.0  'tuple' object has no attribute 'get'
# 1   0.0       0.0  'tuple' object has no attribute 'get'
# 2   0.0       0.0  'tuple' object has no attribute 'get'

# %%
# Export logs to CSV file if there are any logs
if st.session_state.query_logs:
    cleaned_df.to_csv("query_logs.csv", index=False, encoding="utf-8-sig")
    print("Logs exported.")
else:
    print("No logs to export.")
# Out:
# Logs exported.

# %%
query	time	ram_used	Sequence	Question	Query	Response	Time	RAM_Used	Error
0	USE financials;\nSELECT symbol, totalAssets \n...	0.003500	0.0	51.0	เปรียบเทียบสินทรัพย์รวมของบริษัท ADVANC กับบริ...		Error occurred	0.0	0.0	'tuple' object has no attribute 'get'
1	USE financials;\nSELECT symbol, totalLiabiliti...	0.001999	0.0	52.0	เปรียบเทียบหนี้สินรวมของบริษัท ADVANC กับบริษั...		Error occurred	0.0	0.0	'tuple' object has no attribute 'get'
2	USE financials;\nSELECT totalRevenueQuarter \n...	0.002683	0.0	53.0	เปรียบเทียบรายได้รวมในไตรมาสของบริษัท ADVANC ก...		Error occurred	0.0	0.0	'tuple' object has no attribute 'get'
